# %%
pip install pygeohash
# Out:
# ...
# Note: you may need to restart the kernel to use updated packages.

# %%
from sqlalchemy import create_engine
import pandas as pd
import numpy as np
import pygeohash as gh

# %%
engine = create_engine('postgresql://yopter:R3x1q3tjk@yopter.ccyy9l6xansm.us-east-1.redshift.amazonaws.com:5439/yopterdwh')

# %%
df = pd.read_sql_query('SELECT * FROM public.customer_heart_beat limit 20;', engine)

# %%
df['Geohash']=df.apply(lambda x: gh.encode(x.latitude, x.longitude, precision=10), axis=1)

# %%
df
# Out:
#     id_heart_beat  id_customer  id_audience_type                 created_at  \
# 0        143444.0      69779.0               7.0 2016-12-28 17:31:12.040288
# 1        144395.0      29044.0               9.0 2016-12-28 18:58:42.122829
# 2          7708.0      61473.0               6.0 2016-12-17 13:00:13.000000
# 3        134973.0      81479.0               9.0 2016-12-28 00:53:38.609261
# 4          7837.0       9580.0               6.0 2016-11-18 12:02:37.000000
# 5          7855.0       9580.0               6.0 2016-11-18 12:02:37.000000
# 6          7875.0       9580.0               6.0 2016-11-18 12:02:37.000000
# 7          7897.0       9580.0               6.0 2016-11-18 12:02:37.000000
# 8          7918.0      54119.0               6.0 2016-12-17 16:32:15.000000
# 9        135125.0      81497.0               9.0 2016-12-28 01:15:37.894248
# 10       135696.0      80710.0               9.0 2016-12-28 01:40:46.777296
# ...

# %%
df = pd.read_sql_query('SELECT * FROM public.places_interest limit 20;', engine)

# %%
df
# Out:
#     id_place_interest                                             name  \
# 0                   6                                  Feria De Puebla
# 1                   8     Museo De La No Intervención Fuerte De Loreto
# 2                  23                Universidad Iberoamericana Puebla
# 3                  87                                      City Market
# 4                 185    Museo De Las Artes Universidad De Guadalajara
# 5                 241              Parque Metropolitano De Guadalajara
# 6                  12                               Estrella De Puebla
# 7                  24                          Hospital Angeles Puebla
# 8                  36                 Benemerita Universidad De Puebla
# 9                  41                             Tintoreria Arboledas
# 10                 74                            Bosque De Chapultepec
# 11                 29                     La Victoria Centro Comercial
# ...

# %%
df= pd.read_sql_query('SELECT * FROM public.customer_heart_beat ORDER BY id_heart_beat DESC limit 1000;', engine)

# %%
df.head()
# Out:
#    id_heart_beat  id_customer  id_audience_type          created_at  \
# 0   1.622021e+09     462818.0              27.0 2019-07-12 15:00:19
# 1   1.622021e+09    1310005.0              27.0 2019-07-12 15:00:19
# 2   1.622021e+09    1503576.0              27.0 2019-07-12 15:00:19
# 3   1.622021e+09     608902.0              27.0 2019-07-12 15:00:19
# 4   1.622021e+09    1491882.0              27.0 2019-07-12 15:00:19
#
#     latitude   longitude             beat_at
# 0  19.020954  -98.265518 2019-07-12 10:00:20
# 1  28.610655 -106.015495 2019-07-12 09:00:18
# 2  19.419201  -99.129890 2019-07-12 10:00:18
# 3  20.585488 -101.141149 2019-07-12 10:00:19
# 4  19.492266  -99.015289 2019-07-12 09:52:15

# %%
df['Geohash']=df.apply(lambda x: gh.encode(x.latitude, x.longitude, precision=10), axis=1)

# %%
df.head()
# Out:
#    id_heart_beat  id_customer  id_audience_type          created_at  \
# 0   1.622021e+09     462818.0              27.0 2019-07-12 15:00:19
# 1   1.622021e+09    1310005.0              27.0 2019-07-12 15:00:19
# 2   1.622021e+09    1503576.0              27.0 2019-07-12 15:00:19
# 3   1.622021e+09     608902.0              27.0 2019-07-12 15:00:19
# 4   1.622021e+09    1491882.0              27.0 2019-07-12 15:00:19
#
#     latitude   longitude             beat_at     Geohash
# 0  19.020954  -98.265518 2019-07-12 10:00:20  9g6h5ytjp6
# 1  28.610655 -106.015495 2019-07-12 09:00:18  9thdg83v5u
# 2  19.419201  -99.129890 2019-07-12 10:00:18  9g3w2ppv41
# 3  20.585488 -101.141149 2019-07-12 10:00:19  9g8j47rr0m
# 4  19.492266  -99.015289 2019-07-12 09:52:15  9g3wfu7q8t

# %%
dfSubir = df[['id_heart_beat','Geohash']]

# %%
dfSubir.head()
# Out:
#    id_heart_beat     Geohash
# 0   1.622021e+09  9g6h5ytjp6
# 1   1.622021e+09  9thdg83v5u
# 2   1.622021e+09  9g3w2ppv41
# 3   1.622021e+09  9g8j47rr0m
# 4   1.622021e+09  9g3wfu7q8t

# %%
dfSubir.to_sql('Hearts_Geohash', engine, schema='analytics', index=False, if_exists='replace')
# Out:
# C:\Users\Kike\.conda\envs\KikeEnv\lib\site-packages\pandas\io\sql.py:1191: UserWarning: The provided table name 'Hearts_Geohash' is not found exactly as such in the database after writing the table, possibly due to case sensitivity issues. Consider using lower case table names.
#   warnings.warn(msg, UserWarning)
