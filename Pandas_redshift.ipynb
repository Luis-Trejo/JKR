# %%
from sqlalchemy import create_engine
import pandas as pd
import numpy as np
import pandas_redshift as pr

# %%
engine = create_engine('postgresql://yopter:R3x1q3tjk@yopter.ccyy9l6xansm.us-east-1.redshift.amazonaws.com:5439/yopterdwh')

# %%
df = pd.read_sql_query('select * from analytics.customer_place_interest90dias where minutos_mayo > 100', engine)

# %%
pr.connect_to_redshift(dbname = 'yopterdwh',
                        host = 'yopter.ccyy9l6xansm.us-east-1.redshift.amazonaws.com',
                        port = 5439,
                        user = 'yopter',
                        password = 'R3x1q3tjk')

# %%
dfs =  pr.redshift_to_pandas('select * from public.ta_universo_santander_new')

# %%
df.info(verbose=True)
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 12271530 entries, 0 to 12271529
# Data columns (total 14 columns):
# id_place_interest    object
# category             object
# tipo                 object
# id_category          object
# id_customer          float64
# beat_at_min          datetime64[ns]
# beat_at_max          datetime64[ns]
# f_geohash            object
# interacciones        int64
# visitas              int64
# minutos_mayo         int64
# waitmeanminute       int64
# stddevsamp           float64
# mes                  object
# dtypes: datetime64[ns](2), float64(2), int64(4), object(6)
# memory usage: 1.3+ GB

# %%
dfs.info(verbose=True)
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 88965 entries, 0 to 88964
# Data columns (total 55 columns):
# info_date                88965 non-null datetime64[ns]
# id_audience_type         88965 non-null int64
# audience_type            88965 non-null object
# id_customer              88965 non-null int64
# created_at               88965 non-null datetime64[ns]
# email                    88965 non-null object
# gender                   88965 non-null object
# birthday                 87317 non-null datetime64[ns]
# age                      87317 non-null float64
# id_customer_status       88965 non-null int64
# customer_status          88965 non-null object
# id_country               88965 non-null int64
# country                  88965 non-null object
# id_state                 88416 non-null float64
# state                    88965 non-null object
# township                 88965 non-null object
# zip_code                 20274 non-null float64
# ...

# %%
df_join = pd.merge(left=dfs,right=df, how='left', left_on='id_customer', right_on='id_customer')

# %%
df_join.loc[df_join.minutos_mayo > 0]
# Out:
#                         info_date  id_audience_type            audience_type  \
# 65     2019-07-17 03:00:01.684769                 9  Santander Universidades
# 66     2019-07-17 03:00:01.684769                 9  Santander Universidades
# 67     2019-07-17 03:00:01.684769                 9  Santander Universidades
# 68     2019-07-17 03:00:01.684769                 9  Santander Universidades
# 69     2019-07-17 03:00:01.684769                 9  Santander Universidades
# 70     2019-07-17 03:00:01.684769                 9  Santander Universidades
# 71     2019-07-17 03:00:01.684769                 9  Santander Universidades
# 72     2019-07-17 03:00:01.684769                 9  Santander Universidades
# 73     2019-07-17 03:00:01.684769                 9  Santander Universidades
# 74     2019-07-17 03:00:01.684769                 9  Santander Universidades
# 75     2019-07-17 03:00:01.684769                 9  Santander Universidades
# ...

# %%
df =  pr.redshift_to_pandas('select * from analytics.customer_place_interest90dias where id_category = 1321 and minutos_mayo > 480')

# %%
df_join = pd.merge(left=dfs,right=df, how='left', left_on='id_customer', right_on='id_customer')

# %%
df_join.loc[df_join.minutos_mayo > 0]
# Out:
#                        info_date  id_audience_type            audience_type  \
# 81    2019-07-17 03:00:01.684769                 9  Santander Universidades
# 1155  2019-07-17 03:00:01.684769                 9  Santander Universidades
# 1995  2019-07-17 03:00:01.684769                 9  Santander Universidades
# 1996  2019-07-17 03:00:01.684769                 9  Santander Universidades
# 1997  2019-07-17 03:00:01.684769                 9  Santander Universidades
# 1998  2019-07-17 03:00:01.684769                 9  Santander Universidades
# 1999  2019-07-17 03:00:01.684769                 9  Santander Universidades
# 2707  2019-07-17 03:00:01.684769                 9  Santander Universidades
# 2708  2019-07-17 03:00:01.684769                 9  Santander Universidades
# 2709  2019-07-17 03:00:01.684769                 9  Santander Universidades
# 2710  2019-07-17 03:00:01.684769                 9  Santander Universidades
# ...

# %%
dfh =  pr.redshift_to_pandas('select * from public.consulta_heart where max_beat_at > 2019-05-01')

# %%
dfh.count()
# Out:
# id_customer    1067104
# min_beat_at    1067104
# max_beat_at    1067104
# numweeks       1067104
# conteo         1067104
# dtype: int64

# %% [markdown]
# ## Clientes Santander con Hearts despues de mayo

# %%
df_join = pd.merge(left=dfs,right=dfh, how='left', left_on='id_customer', right_on='id_customer')

# %%
df_join.tail()
# Out:
#                        info_date  id_audience_type            audience_type  \
# 88960 2019-07-17 03:00:01.684769                 9  Santander Universidades
# 88961 2019-07-17 03:00:01.684769                 9  Santander Universidades
# 88962 2019-07-17 03:00:01.684769                 9  Santander Universidades
# 88963 2019-07-17 03:00:01.684769                 9  Santander Universidades
# 88964 2019-07-17 03:00:01.684769                 9  Santander Universidades
#
#        id_customer          created_at                        email gender  \
# 88960       108892 2017-04-18 14:03:13     katiasofia16@hotmail.com      F
# 88961        23510 2016-07-20 14:27:17      bren_279210@hotmail.com      F
# 88962      1172464 2018-12-21 21:17:50          kscl-96@hotmail.com      F
# 88963      1161968 2018-12-18 09:58:17  juan_maxter1993@hotmail.com      M
# 88964        51649 2016-10-03 23:43:26      irvinrockstar@gmail.com      M
#
# ...

# %%
df_join.loc[df_join.conteo > 0]
# Out:
#                        info_date  id_audience_type            audience_type  \
# 1     2019-07-17 03:00:01.684769                 9  Santander Universidades
# 2     2019-07-17 03:00:01.684769                 9  Santander Universidades
# 3     2019-07-17 03:00:01.684769                 9  Santander Universidades
# 6     2019-07-17 03:00:01.684769                 9  Santander Universidades
# 7     2019-07-17 03:00:01.684769                 9  Santander Universidades
# 10    2019-07-17 03:00:01.684769                 9  Santander Universidades
# 12    2019-07-17 03:00:01.684769                 9  Santander Universidades
# 22    2019-07-17 03:00:01.684769                 9  Santander Universidades
# 24    2019-07-17 03:00:01.684769                 9  Santander Universidades
# 27    2019-07-17 03:00:01.684769                 9  Santander Universidades
# 28    2019-07-17 03:00:01.684769                 9  Santander Universidades
# ...

# %%
df =  pr.redshift_to_pandas('select * from analytics.customer_place_interest90dias where id_category = 1321 and minutos_mayo > 0')

# %%
df_join = pd.merge(left=dfs,right=df, how='left', left_on='id_customer', right_on='id_customer')

# %%
df_join.loc[df_join.minutos_mayo > 0]
# Out:
#                        info_date  id_audience_type            audience_type  \
# 72    2019-07-17 03:00:01.684769                 9  Santander Universidades
# 73    2019-07-17 03:00:01.684769                 9  Santander Universidades
# 74    2019-07-17 03:00:01.684769                 9  Santander Universidades
# 83    2019-07-17 03:00:01.684769                 9  Santander Universidades
# 84    2019-07-17 03:00:01.684769                 9  Santander Universidades
# 85    2019-07-17 03:00:01.684769                 9  Santander Universidades
# 112   2019-07-17 03:00:01.684769                 9  Santander Universidades
# 708   2019-07-17 03:00:01.684769                 9  Santander Universidades
# 709   2019-07-17 03:00:01.684769                 9  Santander Universidades
# 710   2019-07-17 03:00:01.684769                 9  Santander Universidades
# 711   2019-07-17 03:00:01.684769                 9  Santander Universidades
# ...
