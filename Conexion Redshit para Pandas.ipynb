# %%
from sqlalchemy import create_engine
import pandas as pd
import numpy as np

# %%
engine = create_engine('postgresql://ltrejo:Kj0nzX32Y@yopter.ccyy9l6xansm.us-east-1.redshift.amazonaws.com:5439/yopterdwh')

# %%
catalogo = pd.read_csv("C:/Users/Kike/Documents/MEGA/Yopter/Catalogo_IRS_Coneval.csv",encoding="ISO-8859-1")

# %%
catalogo.head(10)
# Out:
#    Clave_Estado   Nombre_Estado  Clave_Mun           Nombre_Mun  IRS_2015  \
# 0           1.0  Aguascalientes     1001.0       Aguascalientes  Muy bajo
# 1           1.0  Aguascalientes     1002.0             Asientos      Bajo
# 2           1.0  Aguascalientes     1003.0             Calvillo      Bajo
# 3           1.0  Aguascalientes     1004.0                Cosío  Muy bajo
# 4           1.0  Aguascalientes     1005.0          Jesús María  Muy bajo
# 5           1.0  Aguascalientes     1006.0  Pabellón de Arteaga  Muy bajo
# 6           1.0  Aguascalientes     1007.0      Rincón de Romos  Muy bajo
# 7           1.0  Aguascalientes     1008.0   San José de Gracia      Bajo
# 8           1.0  Aguascalientes     1009.0             Tepezalá      Bajo
# 9           1.0  Aguascalientes     1010.0             El Llano      Bajo
#
#   Nivel_Socioe
# 0            A
# 1            B
# 2            B
# 3            A
# 4            A
# 5            A
# 6            A
# 7            B
# ...

# %%
catalogo.to_sql('Cat_Coneval_Nivel_Socieoec', engine, schema='analytics', index=False, if_exists='replace')
# Out:
# ---------------------------------------------------------------------------
# ProgrammingError                          Traceback (most recent call last)
# ~\.conda\envs\KikeEnv\lib\site-packages\sqlalchemy\engine\base.py in _execute_context(self, dialect, constructor, statement, parameters, *args)
#    1243                     self.dialect.do_execute(
# -> 1244                         cursor, statement, parameters, context
#    1245                     )
#
# ~\.conda\envs\KikeEnv\lib\site-packages\sqlalchemy\engine\default.py in do_execute(self, cursor, statement, parameters, context)
#     549     def do_execute(self, cursor, statement, parameters, context=None):
# --> 550         cursor.execute(statement, parameters)
#     551
#
# ProgrammingError: permission denied for schema analytics
#
#
# The above exception was the direct cause of the following exception:
#
# ProgrammingError                          Traceback (most recent call last)
# ...

# %%
df.head()
# Out:
#    id_place_interest  id_category                category
# 0                  3         1321             Universidad
# 1                  6         1267               Auditorio
# 2                  6         1255                  Parque
# 3                  9         1330  Centro de exposiciones
# 4                  9         1269                  Teatro

# %%
df.loc[df['category'] == "Restaurante"]
# Out:
#        id_place_interest  id_category     category
# 8                     20         1303  Restaurante
# 9                     20         1303  Restaurante
# 10                    20         1303  Restaurante
# 42                   365         1303  Restaurante
# 45                   483         1303  Restaurante
# 53                   491         1303  Restaurante
# 54                   491         1303  Restaurante
# 65                   470         1303  Restaurante
# 66                   470         1303  Restaurante
# 67                   470         1303  Restaurante
# 128                   39         1303  Restaurante
# 134                   13         1303  Restaurante
# 135                   13         1303  Restaurante
# 139                   39         1303  Restaurante
# 143                  471         1303  Restaurante
# 144                  473         1303  Restaurante
# 145                  473         1303  Restaurante
# ...

# %%
df = df.pivot_table(index="id_category", values="id_place_interest", columns= aggfunc="count",fill_value=0)

# %%
df.loc[df['id_category'] == "1303"]
# Out:
#              id_place_interest
# id_category
# 1250                        97
# 1251                        54
# 1252                        18
# 1253                         5
# 1254                        69
# 1255                        58
# 1256                        16
# 1257                        28
# 1258                         3
# 1259                         3
# 1260                         3
# 1261                         3
# 1262                         5
# 1263                        22
# 1264                         3
# 1265                         3
# 1266                         3
# 1267                       460
# 1268                        18
# 1269                        14
# 1270                         3
# 1271                         3
# 1272                         3
# 1273                       781
# 1274                        65
# 1275                         5
# 1276                         4
# 1277                         3
# ...
